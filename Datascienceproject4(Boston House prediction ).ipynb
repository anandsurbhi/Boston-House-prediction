# %% [markdown]
# # Boston Housing Dataset
# problem statement-Predict the median value of owner occupied home

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('Downloads/HousingData.csv')

# %%
data.head(5)
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90    NaN  36.2

# %%
data.tail(5)
# Out:
#         CRIM   ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 501  0.06263  0.0  11.93   0.0  0.573  6.593  69.1  2.4786    1  273     21.0
# 502  0.04527  0.0  11.93   0.0  0.573  6.120  76.7  2.2875    1  273     21.0
# 503  0.06076  0.0  11.93   0.0  0.573  6.976  91.0  2.1675    1  273     21.0
# 504  0.10959  0.0  11.93   0.0  0.573  6.794  89.3  2.3889    1  273     21.0
# 505  0.04741  0.0  11.93   0.0  0.573  6.030   NaN  2.5050    1  273     21.0
#
#           B  LSTAT  MEDV
# 501  391.99    NaN  22.4
# 502  396.90   9.08  20.6
# 503  396.90   5.64  23.9
# 504  393.45   6.48  22.0
# 505  396.90   7.88  11.9

# %%
data.shape
# Out:
# (506, 14)

# %%
data.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  486.000000  486.000000  486.000000  486.000000  506.000000  506.000000
# mean     3.611874   11.211934   11.083992    0.069959    0.554695    6.284634
# std      8.720192   23.388876    6.835896    0.255340    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.081900    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.253715    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.560263   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  486.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.518519    3.795043    9.549407  408.237154   18.455534  356.674032
# std     27.999513    2.105710    8.707259  168.537116    2.164946   91.294864
# min      2.900000    1.129600    1.000000  187.000000   12.600000    0.320000
# 25%     45.175000    2.100175    4.000000  279.000000   17.400000  375.377500
# 50%     76.800000    3.207450    5.000000  330.000000   19.050000  391.440000
# 75%     93.975000    5.188425   24.000000  666.000000   20.200000  396.225000
# max    100.000000   12.126500   24.000000  711.000000   22.000000  396.900000
#
#             LSTAT        MEDV
# count  486.000000  506.000000
# mean    12.715432   22.532806
# std      7.155871    9.197104
# min      1.730000    5.000000
# 25%      7.125000   17.025000
# 50%     11.430000   21.200000
# 75%     16.955000   25.000000
# max     37.970000   50.000000

# %%
data.columns
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'B', 'LSTAT', 'MEDV'],
#       dtype='object')

# %%
data.dtypes
# Out:
# CRIM       float64
# ZN         float64
# INDUS      float64
# CHAS       float64
# NOX        float64
# RM         float64
# AGE        float64
# DIS        float64
# RAD          int64
# TAX          int64
# PTRATIO    float64
# B          float64
# LSTAT      float64
# MEDV       float64
# dtype: object

# %%
data.nunique()
# Out:
# CRIM       484
# ZN          26
# INDUS       76
# CHAS         2
# NOX         81
# RM         446
# AGE        348
# DIS        412
# RAD          9
# TAX         66
# PTRATIO     46
# B          357
# LSTAT      438
# MEDV       229
# dtype: int64

# %%
data.isnull().sum()
# Out:
# CRIM       20
# ZN         20
# INDUS      20
# CHAS       20
# NOX         0
# RM          0
# AGE        20
# DIS         0
# RAD         0
# TAX         0
# PTRATIO     0
# B           0
# LSTAT      20
# MEDV        0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     486 non-null    float64
#  1   ZN       486 non-null    float64
#  2   INDUS    486 non-null    float64
#  3   CHAS     486 non-null    float64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      486 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    int64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    486 non-null    float64
#  13  MEDV     506 non-null    float64
# dtypes: float64(12), int64(2)
# memory usage: 55.5 KB

# %%
new_data = data[['RM','TAX','PTRATIO','LSTAT','MEDV']]
new_data.head(5)
# Out:
#       RM  TAX  PTRATIO  LSTAT  MEDV
# 0  6.575  296     15.3   4.98  24.0
# 1  6.421  242     17.8   9.14  21.6
# 2  7.185  242     17.8   4.03  34.7
# 3  6.998  222     18.7   2.94  33.4
# 4  7.147  222     18.7    NaN  36.2

# %%
# Finding the correlation between features
corr=data.corr()
corr.shape
# Out:
# (14, 14)

# %%
#plotting the heatmap of correlation feature
plt.figure(figsize=(20,16))
sns.heatmap(corr, cbar=True,square= True,fmt='.1f', annot=True, annot_kws={'size':15}, cmap='Greens')
# Out:
# <Axes: >

# %% [markdown]
# Univariate and Bivariate Analysis
#
# # 1. MEDV

# %%
plt.figure(figsize=(20,3))
plt.subplot(1,2,1)

sns.boxplot(new_data.MEDV,color='#005030')
plt.title("Box plot of MEDV")

plt.figure(figsize=(20,3))
plt.subplot(1,2,2)

sns.histplot(new_data['MEDV'],kde=True,color='#500050')
plt.title("Distribution plot")
plt.show()

# %% [markdown]
# Removing outliers from the dataset

# %%
new_data.head(5)
# Out:
#       RM  TAX  PTRATIO  LSTAT  MEDV
# 0  6.575  296     15.3   4.98  24.0
# 1  6.421  242     17.8   9.14  21.6
# 2  7.185  242     17.8   4.03  34.7
# 3  6.998  222     18.7   2.94  33.4
# 4  7.147  222     18.7    NaN  36.2

# %%
print(f'Shape of dataset before removing Outliers: {data.shape}')
new_data1 = new_data[~(new_data['MEDV']==50)]
print(f'Shape of dataset after removing Outliers: {new_data.shape}')
# Out:
# Shape of dataset before removing Outliers: (506, 14)
# Shape of dataset after removing Outliers: (506, 5)

# %%
new_data1.head(5)
# Out:
#       RM  TAX  PTRATIO  LSTAT  MEDV
# 0  6.575  296     15.3   4.98  24.0
# 1  6.421  242     17.8   9.14  21.6
# 2  7.185  242     17.8   4.03  34.7
# 3  6.998  222     18.7   2.94  33.4
# 4  7.147  222     18.7    NaN  36.2

# %% [markdown]
# # TAX

# %%
plt.figure(figsize=(20,3))
plt.subplot(1,3,1)
sns.boxplot(new_data.TAX,color='#005030')
plt.title("Box plot of a TAX")

plt.figure(figsize=(20,3))
plt.subplot(1,3,2)
sns.histplot(new_data['TAX'],color='#500050')
plt.title("Histogram distribution of a TAX")


plt.figure(figsize=(20,3))
plt.subplot(1,3,3)
sns.scatterplot(x='TAX',y='MEDV',data=new_data)
plt.title("Scatter plot distribution of the TAX and MEDV")
# Out:
# Text(0.5, 1.0, 'Scatter plot distribution of the TAX and MEDV')

# %%
df = new_data1[new_data1['TAX']>600].sort_values(by=['RM','MEDV'])
df.shape
# Out:
# (132, 5)

# %%
df
# Out:
#         RM  TAX  PTRATIO  LSTAT  MEDV
# 365  3.561  666     20.2   7.12  27.5
# 367  3.863  666     20.2  13.33  23.1
# 406  4.138  666     20.2  23.34  11.9
# 374  4.138  666     20.2  37.97  13.8
# 384  4.368  666     20.2  30.63   8.8
# ..     ...  ...      ...    ...   ...
# 473  6.980  666     20.2    NaN  29.8
# 482  7.061  666     20.2   7.01  25.0
# 375  7.313  666     20.2  13.44  15.0
# 453  7.393  666     20.2  16.74  17.8
# 364  8.780  666     20.2   5.29  21.9
#
# [132 rows x 5 columns]

# %%
desc=df.describe().round(2)
desc
# Out:
#            RM     TAX  PTRATIO   LSTAT    MEDV
# count  132.00  132.00   132.00  126.00  132.00
# mean     6.00  667.70    20.20   19.18   14.99
# std      0.71    8.62     0.02    6.54    5.41
# min      3.56  666.00    20.10    5.29    5.00
# 25%      5.67  666.00    20.20   14.66   10.90
# 50%      6.14  666.00    20.20   18.06   14.10
# 75%      6.41  666.00    20.20   23.28   19.20
# max      8.78  711.00    20.20   37.97   29.80

# %% [markdown]
# # LSTAT

# %%
plt.figure(figsize=(20, 3))

# Box plot of LSTAT
plt.subplot(1, 3, 1)
sns.boxplot(y='LSTAT', data=df, color='#005030')
plt.title('Box Plot of LSTAT')

# Distribution plot of LSTAT
plt.subplot(1, 3, 2)
sns.histplot(df['LSTAT'], kde=True, color='#500050')
plt.title('Distribution Plot of LSTAT')

# Scatter plot of LSTAT vs MEDV
plt.subplot(1, 3, 3)
sns.scatterplot(x='LSTAT', y='MEDV', data=df)
plt.title('Scatter Plot of LSTAT vs MEDV')

# Show the plots
plt.show()

# %%
LSTAT_Q3 = desc['LSTAT']['75%']
LSTAT_Q1 = desc['LSTAT']['25%']
LSTAT_IQR = LSTAT_Q3 - LSTAT_Q1
LSTAT_UV = LSTAT_Q3 + 1.5 * LSTAT_IQR
LSTAT_LV = LSTAT_Q1 - 1.5 * LSTAT_IQR

# Filter and sort df2 for values exceeding the upper bound
outliers = df[df['LSTAT'] > LSTAT_UV].sort_values(by='LSTAT')

# Display the outliers
print(outliers)
# Out:
#         RM  TAX  PTRATIO  LSTAT  MEDV
# 414  4.519  666     20.2  36.98   7.0
# 374  4.138  666     20.2  37.97  13.8

# %%
plt.figure(figsize=(20,3))

plt.subplot(1,3,1)
sns.boxplot(y='RM',data=df,color='#005030')
plt.title('Box Plot of MEDV')

plt.subplot(1,3,2)
sns.histplot(df['RM'],color='#500050')
plt.title('Distribution Plot of MEDV')

plt.subplot(1,3,3)
sns.scatterplot(x='RM',y='MEDV',data=df)
plt.title('Scatter Plot of RM vs MEDV')

plt.show()

# %%
RM_Q3 = desc['RM']['75%']
RM_Q1 = desc['RM']['25%']
RM_IQR = RM_Q3 - RM_Q1
RM_UV = RM_Q3 + 1.5*RM_IQR
RM_LV = RM_Q1 - 1.5*RM_IQR

df[df['RM']<RM_LV].sort_values(by=['RM','MEDV'])
# Out:
#         RM  TAX  PTRATIO  LSTAT  MEDV
# 365  3.561  666     20.2   7.12  27.5
# 367  3.863  666     20.2  13.33  23.1
# 406  4.138  666     20.2  23.34  11.9
# 374  4.138  666     20.2  37.97  13.8
# 384  4.368  666     20.2  30.63   8.8
# 414  4.519  666     20.2  36.98   7.0

# %%
print(f'Shape of dataset before removing data points: {new_data1.shape}')
df3 = new_data1.drop(axis=0,index=[365,367])
print(f'Shape of dataset before removing data points: {df3.shape}')
# Out:
# Shape of dataset before removing data points: (490, 5)
# Shape of dataset before removing data points: (488, 5)

# %%
df3[df3['RM']>RM_UV].sort_values(by=['RM','MEDV'])
# Out:
#         RM  TAX  PTRATIO  LSTAT  MEDV
# 202  7.610  348     14.7   3.11  42.3
# 282  7.645  216     14.9   3.01  46.0
# 228  7.686  307     17.4    NaN  46.7
# 273  7.691  223     18.6   6.58  35.2
# 180  7.765  193     17.8   7.56  39.8
# 98   7.820  276     18.0   3.57  43.8
# 280  7.820  216     14.9   3.76  45.4
# 203  7.853  224     14.7   3.81  48.5
# 226  8.040  307     17.4    NaN  37.6
# 97   8.069  276     18.0   4.21  38.7
# 233  8.247  307     17.4   3.95  48.3
# 253  8.259  330     19.1   3.54  42.8
# 224  8.266  307     17.4   4.14  44.8
# 232  8.337  307     17.4   2.47  41.7
# 262  8.398  264     13.0   5.91  48.8
# 364  8.780  666     20.2   5.29  21.9

# %%
print(f'Shape of dataset before removing data points: {df3.shape}')
df3 = df3.drop(axis=0,index=[364])
print(f'Shape of dataset before removing data points: {df3.shape}')
# Out:
# Shape of dataset before removing data points: (488, 5)
# Shape of dataset before removing data points: (487, 5)

# %%
df3['RM']=df3['RM'].fillna(df['RM'].mean())
df3['TAX']=df3['TAX'].fillna(df['TAX'].mean())
df3['PTRATIO']=df3['PTRATIO'].fillna(df['PTRATIO'].mean())
df3['LSTAT']=df3['LSTAT'].fillna(df['LSTAT'].mean())
df3['MEDV']=df3['MEDV'].fillna(df['MEDV'].mean())

# %%
#Now will split our dataset into Dependent variable and Independent variable
X_dt = df3.iloc[:,:-1].values
y_dt = df3.iloc[:,-1].values

# %%
print(f"Shape of Dependent Variable X = {X.shape}")
print(f"Shape of Independent Variable y = {y.shape}")
# Out:
# Shape of Dependent Variable X = (487, 5)
# Shape of Independent Variable y = (487, 1)

# %%
from sklearn.model_selection import train_test_split
X_train_dt,X_test_dt,y_train_dt,y_test_dt = train_test_split(X_dt,y_dt,test_size=0.2,random_state=42)

print(f"Shape of X_train_dt = {X_train_dt.shape}")
print(f"Shape of X_test_dt = {X_test_dt.shape}")
print(f"Shape of y_train_dt = {y_train_dt.shape}")
print(f"Shape of y_test_dt = {y_test_dt.shape}")
# Out:
# Shape of X_train_dt = (389, 4)
# Shape of X_test_dt = (98, 4)
# Shape of y_train_dt = (389,)
# Shape of y_test_dt = (98,)

# %%
from sklearn.tree import DecisionTreeRegressor
dt = DecisionTreeRegressor()
dt.fit(X_train_dt,y_train_dt)
# Out:
# DecisionTreeRegressor()

# %%
y_pred_dt = dt.predict(X_test_dt)
y_pred_dt[:5]
# Out:
# array([22.1, 28.5, 27.9, 19.5, 19.9])

# %%
plt.scatter(x=y_test_dt,y=y_pred_dt,alpha=0.5)
plt.xlabel('y_test',size=12)
plt.ylabel('y_pred',size=12)
plt.title('Predicited Values vs Original Values (Test Set)',size=15)
plt.show()

# %%
sns.distplot(y_pred_dt-y_test_dt)
plt.xlabel('Residual',size=12)
plt.ylabel('Frquency',size=12)
plt.title('Distribution of Residuals',size=15)
plt.show()
# Out:
# /var/folders/8r/pn9yp9cx79q54m6vgfdd844m0000gn/T/ipykernel_40855/745740536.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(y_pred_dt-y_test_dt)

# %%
from sklearn import metrics
r2_dt= metrics.r2_score(y_test_dt,y_pred_dt)
N,p = X_test_dt.shape
adj_r2_dt = 1-((1-r2_dt)*(N-1))/(N-p-1)
print(f'R^2 = {r2_dt}')
print(f'Adjusted R^2 = {adj_r2_dt}')
# Out:
# R^2 = 0.7342608628820929
# Adjusted R^2 = 0.7228312225759463

# %%
from sklearn import metrics
mse_dt = metrics.mean_squared_error(y_test_dt,y_pred_dt)
mae_dt = metrics.mean_absolute_error(y_test_dt,y_pred_dt)
rmse_dt = np.sqrt(metrics.mean_squared_error(y_test_dt,y_pred_dt))
print(f'Mean Squared Error: {mse_dt}',f'Mean Absolute Error: {mae_dt}',f'Root Mean Squared Error: {rmse_dt}',sep='\n')
# Out:
# Mean Squared Error: 19.18183673469387
# Mean Absolute Error: 3.163265306122449
# Root Mean Squared Error: 4.379707380030528

# %% [markdown]
# # RANDOM FOREST

# %%
X_rf = df3.iloc[:,:-1].values
y_rf = df3.iloc[:,-1].values

# %%
from sklearn.model_selection import train_test_split
X_train_rf,X_test_rf,y_train_rf,y_test_rf = train_test_split(X_rf,y_rf,test_size=0.2,random_state=42)

print(f"Shape of X_train_rf = {X_train_rf.shape}")
print(f"Shape of X_test_rf = {X_test_rf.shape}")
print(f"Shape of y_train_rf = {y_train_rf.shape}")
print(f"Shape of y_test_rf = {y_test_rf.shape}")
# Out:
# Shape of X_train_rf = (389, 4)
# Shape of X_test_rf = (98, 4)
# Shape of y_train_rf = (389,)
# Shape of y_test_rf = (98,)

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor(random_state=42)
rf.fit(X_train_rf,y_train_rf)
# Out:
# RandomForestRegressor(random_state=42)

# %%
y_pred_rf = rf.predict(X_test_rf)
y_pred_rf[:5]
# Out:
# array([22.559, 30.677, 21.247, 20.976, 15.695])

# %%
plt.scatter(x=y_test_rf,y=y_pred_rf,alpha=0.5)
plt.xlabel('y_test',size=12)
plt.ylabel('y_pred',size=12)
plt.title('Predicited Values vs Original Values (Test Set)',size=15)
plt.show()

# %%
sns.distplot(y_pred_rf-y_test_rf)
plt.xlabel('Residual',size=12)
plt.ylabel('Frquency',size=12)
plt.title('Distribution of Residuals',size=15)
plt.show()
# Out:
# /var/folders/8r/pn9yp9cx79q54m6vgfdd844m0000gn/T/ipykernel_40855/3464199790.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(y_pred_rf-y_test_rf)

# %%
from sklearn import metrics
r2_rf= metrics.r2_score(y_test_rf,y_pred_rf)
N,p = X_test_dt.shape
adj_r2_rf = 1-((1-r2_rf)*(N-1))/(N-p-1)
print(f'R^2 = {r2_rf}')
print(f'Adjusted R^2 = {adj_r2_rf}')
# Out:
# R^2 = 0.8512870128274393
# Adjusted R^2 = 0.8448907553146411

# %%
from sklearn import metrics
mse_rf = metrics.mean_squared_error(y_test_rf,y_pred_rf)
mae_rf = metrics.mean_absolute_error(y_test_rf,y_pred_rf)
rmse_rf = np.sqrt(metrics.mean_squared_error(y_test_rf,y_pred_rf))
print(f'Mean Squared Error: {mse_rf}',f'Mean Absolute Error: {mae_rf}',f'Root Mean Squared Error: {rmse_rf}',sep='\n')
# Out:
# Mean Squared Error: 10.734543173469412
# Mean Absolute Error: 2.439704081632654
# Root Mean Squared Error: 3.2763612702920004

# %%
results=pd.DataFrame({'Decision Tree':[r2_dt,adj_r2_dt],
                      'Random Forest':[r2_rf,adj_r2_rf]},index=['R square','Adj R square'])

results.plot(kind='bar',alpha=0.7,grid=True,title='Interpreting Results',rot=0,figsize=(10,5),colormap='jet')
results
# Out:
#               Decision Tree  Random Forest
# R square           0.734261       0.851287
# Adj R square       0.722831       0.844891
